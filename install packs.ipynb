# %%
# !pip install tensorflow==2.8.0
# Out:
# Collecting tensorflow==2.8.0
#   Using cached tensorflow-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.14.1-cp39-cp39-win_amd64.whl (35 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting gast>=0.2.1
#   Using cached gast-0.5.3-py3-none-any.whl (19 kB)
# Collecting typing-extensions>=3.6.6
#   Using cached typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# Collecting keras<2.9,>=2.8.0rc0
#   Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.46.3-cp39-cp39-win_amd64.whl (3.5 MB)
# Collecting flatbuffers>=1.12
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting tensorboard<2.9,>=2.8
#   Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting libclang>=9.0.1
#   Using cached libclang-14.0.1-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting absl-py>=0.4.0
#   Using cached absl_py-1.1.0-py3-none-any.whl (123 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.7.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-4.21.1-cp39-cp39-win_amd64.whl (524 kB)
#      -------------------------------------- 524.9/524.9 KB 2.2 MB/s eta 0:00:00
# Collecting numpy>=1.20
#   Using cached numpy-1.22.4-cp39-cp39-win_amd64.whl (14.7 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: setuptools in d:\gpenv\gpenv\lib\site-packages (from tensorflow==2.8.0) (58.1.0)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: six>=1.12.0 in d:\gpenv\gpenv\lib\site-packages (from tensorflow==2.8.0) (1.16.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.26.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.7-py3-none-any.whl (97 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting werkzeug>=0.11.15
#   Using cached Werkzeug-2.1.2-py3-none-any.whl (224 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-4.11.4-py3-none-any.whl (18 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.5.18.1-py3-none-any.whl (155 kB)
#      -------------------------------------- 155.2/155.2 KB 4.7 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Installing collected packages: tf-estimator-nightly, termcolor, tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, zipp, wrapt, wheel, werkzeug, urllib3, typing-extensions, tensorflow-io-gcs-filesystem, tensorboard-data-server, rsa, pyasn1-modules, protobuf, oauthlib, numpy, idna, grpcio, google-pasta, gast, charset-normalizer, certifi, cachetools, absl-py, requests, opt-einsum, keras-preprocessing, importlib-metadata, h5py, google-auth, astunparse, requests-oauthlib, markdown, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-1.1.0 astunparse-1.6.3 cachetools-5.2.0 certifi-2022.5.18.1 charset-normalizer-2.0.12 flatbuffers-2.0 gast-0.5.3 google-auth-2.6.6 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.46.3 h5py-3.7.0 idna-3.3 importlib-metadata-4.11.4 keras-2.8.0 keras-preprocessing-1.1.2 libclang-14.0.1 markdown-3.3.7 numpy-1.22.4 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-4.21.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0 tf-estimator-nightly-2.8.0.dev2021122109 typing-extensions-4.2.0 urllib3-1.26.9 werkzeug-2.1.2 wheel-0.37.1 wrapt-1.14.1 zipp-3.8.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'D:\GPenv\gpenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install tensorflow-gpu==2.8.0
# Out:
# Collecting tensorflow-gpu==2.8.0
#   Downloading tensorflow_gpu-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
#      -------------------------------------- 438.0/438.0 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (14.0.1)
# Requirement already satisfied: setuptools in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (58.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (4.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (1.14.1)
# Requirement already satisfied: protobuf>=3.9.2 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (4.21.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (1.6.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (0.5.3)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (1.16.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: flatbuffers>=1.12 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (0.26.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (1.46.3)
# Requirement already satisfied: numpy>=1.20 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (1.22.4)
# Requirement already satisfied: absl-py>=0.4.0 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\gpenv\gpenv\lib\site-packages (from tensorflow-gpu==2.8.0) (3.7.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\gpenv\gpenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu==2.8.0) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\gpenv\gpenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\gpenv\gpenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\gpenv\gpenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.1.2)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\gpenv\gpenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\gpenv\gpenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\gpenv\gpenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.6.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\gpenv\gpenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\gpenv\gpenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\gpenv\gpenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\gpenv\gpenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\gpenv\gpenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\gpenv\gpenv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (4.11.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\gpenv\gpenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\gpenv\gpenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in d:\gpenv\gpenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\gpenv\gpenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.3)
# Requirement already satisfied: zipp>=0.5 in d:\gpenv\gpenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\gpenv\gpenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\gpenv\gpenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.2.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.8.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'D:\GPenv\gpenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install opencv-python==4.5.5.64
# Out:
# Collecting opencv-python==4.5.5.64
#   Using cached opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl (35.4 MB)
# Requirement already satisfied: numpy>=1.19.3 in d:\gpenv\gpenv\lib\site-packages (from opencv-python==4.5.5.64) (1.22.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'D:\GPenv\gpenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib==3.5.1
# Out:
# Collecting matplotlib==3.5.1
#   Downloading matplotlib-3.5.1-cp39-cp39-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 7.3 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.33.3-py3-none-any.whl (930 kB)
# Requirement already satisfied: packaging>=20.0 in d:\gpenv\gpenv\lib\site-packages (from matplotlib==3.5.1) (21.3)
# Requirement already satisfied: numpy>=1.17 in d:\gpenv\gpenv\lib\site-packages (from matplotlib==3.5.1) (1.22.4)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.2-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\gpenv\gpenv\lib\site-packages (from matplotlib==3.5.1) (3.0.9)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.1.1-cp39-cp39-win_amd64.whl (3.3 MB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\gpenv\gpenv\lib\site-packages (from matplotlib==3.5.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\gpenv\gpenv\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.5.1) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.2 matplotlib-3.5.1 pillow-9.1.1
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'D:\GPenv\gpenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-3.0.12-py3-none-any.whl (5.1 MB)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: pillow in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from gradio) (9.1.1)
# Collecting pycryptodome
#   Downloading pycryptodome-3.14.1-cp35-abi3-win_amd64.whl (1.8 MB)
# Collecting fastapi
#   Downloading fastapi-0.78.0-py3-none-any.whl (54 kB)
# Requirement already satisfied: numpy in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from gradio) (1.22.4)
# Collecting paramiko
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.17.6-py3-none-any.whl (53 kB)
# Requirement already satisfied: Jinja2 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from gradio) (3.0.3)
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Requirement already satisfied: matplotlib in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from gradio) (3.5.1)
# Collecting pandas
#   Downloading pandas-1.4.2-cp39-cp39-win_amd64.whl (10.5 MB)
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
# Collecting orjson
#   Downloading orjson-3.7.1-cp39-none-win_amd64.whl (189 kB)
# Collecting analytics-python
#   Downloading analytics_python-1.4.0-py2.py3-none-any.whl (15 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp39-cp39-win_amd64.whl (554 kB)
# Requirement already satisfied: requests in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from gradio) (2.27.1)
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp39-cp39-win_amd64.whl (33 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp39-cp39-win_amd64.whl (122 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp39-cp39-win_amd64.whl (28 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from aiohttp->gradio) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from aiohttp->gradio) (2.0.12)
# Requirement already satisfied: idna>=2.0 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->gradio) (3.3)
# Requirement already satisfied: python-dateutil>2.1 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from analytics-python->gradio) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from analytics-python->gradio) (1.16.0)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff==1.10.0
#   Downloading backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from requests->gradio) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from requests->gradio) (2022.5.18.1)
# Collecting starlette==0.19.1
#   Downloading starlette-0.19.1-py3-none-any.whl (63 kB)
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from starlette==0.19.1->fastapi->gradio) (4.1.1)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from Jinja2->gradio) (2.0.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.1-py3-none-any.whl (10 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.0-py3-none-any.whl (43 kB)
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from matplotlib->gradio) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from matplotlib->gradio) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from matplotlib->gradio) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from matplotlib->gradio) (3.0.4)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Collecting cryptography>=2.5
#   Downloading cryptography-37.0.2-cp36-abi3-win_amd64.whl (2.4 MB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.2-cp36-abi3-win_amd64.whl (29 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
# Requirement already satisfied: cffi>=1.1 in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from bcrypt>=3.1.3->paramiko->gradio) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->gradio) (2.21)
# Collecting h11>=0.8
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Collecting click>=7.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.5.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: colorama in c:\users\oak\miniconda3\envs\gpab\lib\site-packages (from click>=7.0->uvicorn->gradio) (0.4.4)
# Building wheels for collected packages: ffmpy, python-multipart
#   Building wheel for ffmpy (setup.py): started
#   Building wheel for ffmpy (setup.py): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4712 sha256=44894834f09fd669c7e2874b62169a4f25b55a839c00a06b0c27ee199bf6c408
#   Stored in directory: c:\users\oak\appdata\local\pip\cache\wheels\91\e2\96\f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
#   Building wheel for python-multipart (setup.py): started
#   Building wheel for python-multipart (setup.py): finished with status 'done'
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=2bc1942b3ac913a67e15a5aa74e926fe4a09e2430722c400c8c3cfed0d44add6
#   Stored in directory: c:\users\oak\appdata\local\pip\cache\wheels\fe\04\d1\a10661cc45f03c3cecda50deb2d2c22f57b4e84a75b2a5987e
# Successfully built ffmpy python-multipart
# Installing collected packages: sniffio, mdurl, uc-micro-py, multidict, markdown-it-py, frozenlist, anyio, yarl, starlette, pytz, pynacl, pydantic, monotonic, mdit-py-plugins, linkify-it-py, h11, cryptography, click, bcrypt, backoff, async-timeout, asgiref, aiosignal, uvicorn, python-multipart, pydub, pycryptodome, paramiko, pandas, orjson, ffmpy, fastapi, analytics-python, aiohttp, gradio
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 analytics-python-1.4.0 anyio-3.6.1 asgiref-3.5.2 async-timeout-4.0.2 backoff-1.10.0 bcrypt-3.2.2 click-8.1.3 cryptography-37.0.2 fastapi-0.78.0 ffmpy-0.3.0 frozenlist-1.3.0 gradio-3.0.12 h11-0.13.0 linkify-it-py-1.0.3 markdown-it-py-2.1.0 mdit-py-plugins-0.3.0 mdurl-0.1.1 monotonic-1.6 multidict-6.0.2 orjson-3.7.1 pandas-1.4.2 paramiko-2.11.0 pycryptodome-3.14.1 pydantic-1.9.1 pydub-0.25.1 pynacl-1.5.0 python-multipart-0.0.5 pytz-2022.1 sniffio-1.2.0 starlette-0.19.1 uc-micro-py-1.0.1 uvicorn-0.17.6 yarl-1.7.2

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      1.1.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# backcall                     0.2.0
# cachetools                   5.2.0
# certifi                      2022.5.18.1
# charset-normalizer           2.0.12
# colorama                     0.4.4
# cycler                       0.11.0
# debugpy                      1.6.0
# decorator                    5.1.1
# entrypoints                  0.4
# executing                    0.8.3
# flatbuffers                  2.0
# fonttools                    4.33.3
# gast                         0.5.3
# google-auth                  2.6.6
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.46.3
# h5py                         3.7.0
# idna                         3.3
# importlib-metadata           4.11.4
# ipykernel                    6.13.1
# ipython                      8.4.0
# jedi                         0.18.1
# jupyter-client               7.3.2
# jupyter-core                 4.10.0
# keras                        2.8.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.2
# libclang                     14.0.1
# Markdown                     3.3.7
# matplotlib                   3.5.1
# matplotlib-inline            0.1.3
# nest-asyncio                 1.5.5
# numpy                        1.22.4
# oauthlib                     3.2.0
# opencv-python                4.5.5.64
# opt-einsum                   3.3.0
# packaging                    21.3
# parso                        0.8.3
# pickleshare                  0.7.5
# Pillow                       9.1.1
# pip                          22.0.4
# prompt-toolkit               3.0.29
# protobuf                     4.21.1
# psutil                       5.9.1
# pure-eval                    0.2.2
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# Pygments                     2.12.0
# pyparsing                    3.0.9
# python-dateutil              2.8.2
# pywin32                      304
# pyzmq                        23.1.0
# requests                     2.27.1
# requests-oauthlib            1.3.1
# rsa                          4.8
# setuptools                   58.1.0
# six                          1.16.0
# stack-data                   0.2.0
# tensorboard                  2.8.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.8.0
# tensorflow-gpu               2.8.0
# tensorflow-io-gcs-filesystem 0.26.0
# termcolor                    1.1.0
# tf-estimator-nightly         2.8.0.dev2021122109
# tornado                      6.1
# traitlets                    5.2.2.post1
# typing_extensions            4.2.0
# urllib3                      1.26.9
# wcwidth                      0.2.5
# Werkzeug                     2.1.2
# wheel                        0.37.1
# wrapt                        1.14.1
# zipp                         3.8.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'D:\GPenv\gpenv\Scripts\python.exe -m pip install --upgrade pip' command.
